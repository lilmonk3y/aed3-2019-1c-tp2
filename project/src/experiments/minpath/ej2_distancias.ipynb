# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Se generaron 10 grafos de n vértices para n en [3, 20] saltando de 5 en 5
# y con probabilidad 0.75 de que un vértice dado exista.

# Luego se corre cada grafo 20 veces para evitar variaciones de tiempos del SO.

dfShort = pd.read_csv("./salidas/ej2/tiempos_4_salida_grafos_random_10_10_20_2_0.0_1_15.csv") # Creo un dataframe desde el csv
dfShort = df.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
print(dfShort)

dfLong = pd.read_csv("./salidas/ej2/tiempos_5_salida_grafos_random_10_10_20_2_0.0_16_60.csv") # Creo un dataframe desde el csv
dfLong = dfLong.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
print(dfLong)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-f44d16584fa1> in <module>()
#       8 # Luego se corre cada grafo 20 veces para evitar variaciones de tiempos del SO.
#       9
# ---> 10 dfShort = pd.read_csv("./salidas/ej2/tiempos_4_salida_grafos_random_10_10_20_2_0.0_1_15.csv") # Creo un dataframe desde el csv
#      11 dfShort = df.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
#      12 print(dfShort)
#
# ...

# %% [markdown]
# # Comparación

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfShort, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfShort, color="red");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfShort, color="orange");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfShort, color="green");

#eje_cartesiano.set_title("Distancias cortas")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Floyd-Warshall", "Dijkstra con cola de prioridad", "Dijkstra con cola FIFO"]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b27a2aed5bbf> in <module>()
#       1 fig = plt.figure()
# ----> 2 eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfShort, color="blue");
#       3 eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfShort, color="red");
#       4 eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfShort, color="orange");
#       5 eje_cartesiano = sns.lineplot(x="n", y="df", data=dfShort, color="green");
#
# NameError: name 'dfShort' is not defined

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfShort, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfShort, color="green");

#eje_cartesiano.set_title("Distancias cortas")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vértices");
eje_cartesiano.legend(["Bellman-Ford", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLong, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfLong, color="red");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfLong, color="orange");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLong, color="green");

#eje_cartesiano.set_title("Distancias largas")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vértices");
eje_cartesiano.legend(["Bellman-Ford", "Floyd-Warshall", "Dijkstra con cola de prioridad", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLong, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLong, color="green");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfLong, color="orange");


#eje_cartesiano.set_title("Distancias largas")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vértices");
eje_cartesiano.legend(["Bellman-Ford", "Dijkstra con cola FIFO", "Dijkstra con cola de prioridad"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLong, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLong, color="green");


#eje_cartesiano.set_title("Distancias largas")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vértices");
eje_cartesiano.legend(["Bellman-Ford", "Dijkstra con cola FIFO"]);

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Se generaron 10 grafos de n vértices para n en [3, 20] saltando de 5 en 5
# y con probabilidad 0.75 de que un vértice dado exista.

# Luego se corre cada grafo 20 veces para evitar variaciones de tiempos del SO.

dfLow = pd.read_csv("./salidas/exp1/tiempos_1_salida_grafos_random_10_10_20_2_0.0.csv") # Creo un dataframe desde el csv
dfLow = dfLow.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
print(dfLow)

dfMedium = pd.read_csv("./salidas/exp1/tiempos_2_salida_grafos_random_10_10_20_2_0.5.csv") # Creo un dataframe desde el csv
dfMedium = dfMedium.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
print(dfMedium)

dfComplete = pd.read_csv("./salidas/exp1/tiempos_3_salida_grafos_random_10_10_20_2_1.0.csv") # Creo un dataframe desde el csv
dfComplete = dfComplete.groupby("n", as_index=False).mean() # Promedio para cada n en milisegundos
print(dfComplete)
# Out:
#     n   m        bf          fw         dp        df
# 0  10   9  0.835421   303.19640   4.353527  0.756809
# 1  12  11  1.517478  1385.09996   8.405083  1.719158
# 2  14  13  1.872354  1606.02960   9.573676  1.912382
# 3  16  15  3.696484  3400.30240  16.410656  3.319541
# 4  18  17  3.484701  3113.65530  16.049648  2.674301
# 5  20  19  4.045246  4365.00430  19.918980  3.261611
#     n   m         bf          fw         dp         df
# 0  10  22   1.478952   317.46372   5.999832   1.520395
# 1  12  33   7.755862  1425.56652  19.419216   7.213984
# 2  14  45  13.146590  1673.44920  23.039365  13.081797
# 3  16  60  38.962308  3336.79760  45.729085  33.622679
# 4  18  76  35.497625  3181.72220  49.077682  32.104489
# 5  20  95  59.348349  4242.11710  68.102487  47.852174
#     n    m         bf          fw         dp         df
# 0  10   45   2.720393   334.32675   9.637386   2.650670
# 1  12   66  16.954568  1496.67131  25.604405  14.645718
# ...

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLow, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfLow, color="red");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfLow, color="orange");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLow, color="green");

eje_cartesiano.set_title("Densidad minima")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Floyd-Warshall", "Dijkstra con cola de prioridad", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLow, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLow, color="green");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfLow, color="orange");


eje_cartesiano.set_title("Densidad minima")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Dijkstra con cola FIFO", "Dijkstra con cola de prioridad"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfLow, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfLow, color="green");


eje_cartesiano.set_title("Densidad minima")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfMedium, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfMedium, color="red");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfMedium, color="orange");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfMedium, color="green");

eje_cartesiano.set_title("Densidad media")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Floyd-Warshall", "Dijkstra con cola de prioridad", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfMedium, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfMedium, color="green");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfMedium, color="orange");


eje_cartesiano.set_title("Densidad media")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford","Dijkstra con cola FIFO", "Dijkstra con cola de prioridad"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfComplete, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="fw", data=dfComplete, color="red");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfComplete, color="orange");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfComplete, color="green");

eje_cartesiano.set_title("Densidad maxima")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford", "Floyd-Warshall", "Dijkstra con cola de prioridad", "Dijkstra con cola FIFO"]);

# %%
fig = plt.figure()
eje_cartesiano = sns.lineplot(x="n", y="bf", data=dfComplete, color="blue");
eje_cartesiano = sns.lineplot(x="n", y="df", data=dfComplete, color="green");
eje_cartesiano = sns.lineplot(x="n", y="dp", data=dfComplete, color="orange");


eje_cartesiano.set_title("Densidad maxima")
plt.ylabel("Tiempo (ms)");
plt.xlabel("Cantidad de vertices");
eje_cartesiano.legend(["Bellman-Ford","Dijkstra con cola FIFO", "Dijkstra con cola de prioridad"]);
